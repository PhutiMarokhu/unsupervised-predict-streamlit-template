# %% [markdown]
# # EDSA Movie Recommendation Challenge
# #### Flex your Unsupervised Learning skills to generate movie recommendations
#
# ### ![image.png](attachment:image.png)

# %% [markdown]
# # Unsupervised_Learning_Team_AM4 Predict Notebook
# #### Team Members:Phuti Marokhu,Sibongile Maluleka,Thabang,Morgan,Montgomery Malope,Odi
